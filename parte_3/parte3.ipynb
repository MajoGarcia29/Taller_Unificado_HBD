# %% [markdown]
# # Parte 3 Workshop

# %% [markdown]
# ## Ejecución del Pipeline de Datos de YouTube Trending

# %%
from youtube_pipeline import youtube_trending_pipeline

youtube_trending_pipeline()
# Out:
# 07:52:56.387 | INFO    | prefect - Starting temporary server on http://127.0.0.1:8989
# See https://docs.prefect.io/v3/concepts/server#how-to-guides for more information on running a dedicated Prefect server.
# 07:53:12.868 | INFO    | Flow run 'lyrical-kangaroo' - Beginning flow run 'lyrical-kangaroo' for flow 'youtube_trending_pipeline'
# 07:53:12.932 | INFO    | Task run 'crear_directorios_staging-c6d' - Directorios de staging listos: staging\youtube_raw, staging\youtube_processed
# 07:53:12.939 | INFO    | Task run 'crear_directorios_staging-c6d' - Finished in state Completed()
# 07:53:12.952 | WARNING | Task run 'descargar_dataset_kaggle-b3e' - No se pudo descargar desde Kaggle (No module named 'kaggle'). Generando datos de muestra sintéticos para demostración…
# ...

# %% [markdown]
# ## Carga y visualización del dataset procesado

# %%
import pandas as pd

df = pd.read_csv("staging/youtube_processed/youtube_top100_global.csv")
df.head()
# Out:
#       video_id trending_date          title channel_title  category_id  \
# 0  kiZmVObTXgX      18.11.02  Video DE #003     Channel_2           15
# 1  xOFlxwNMOJx      18.02.05  Video KR #058    Channel_35            4
# 2  cHHaSQImQdW      18.05.05  Video RU #152    Channel_12           23
# 3  SMReScocQjg      18.01.08  Video MX #049    Channel_42           13
# 4  ckVsyxcYqKB      17.08.08  Video GB #002    Channel_18           27
#
#                publish_time       tags     views    likes  dislikes  ...  \
# 0  2018-02-08T21:13:00.000Z  tag1|tag2  49975127  1792362     97081  ...
# 1  2018-03-03T06:15:00.000Z  tag1|tag2  49948280  1418799     49477  ...
# 2  2018-03-25T14:53:00.000Z  tag1|tag2  49914971   412410      1703  ...
# 3  2018-08-21T09:22:00.000Z  tag1|tag2  49871704  1693226     68354  ...
# 4  2017-02-09T11:14:00.000Z  tag1|tag2  49838717   553213     75942  ...
#
#                          description country  trending_date_std  \
# ...

# %% [markdown]
# ## Carga del dataset unificado (Top 100 global)

# %%
import pandas as pd

df = pd.read_csv("staging/youtube_processed/youtube_top100_global.csv")

# %% [markdown]
# ## Integración con MongoDB y almacenamiento de datos mediante Prefect

# %%
from pymongo import MongoClient
from prefect import flow, task

client = MongoClient("mongodb+srv://admin:sara1234@cluster0.rbrydik.mongodb.net/?appName=Cluster0")
db = client["youtube_db"]
collection = db["top100"]

@task
def guardar_mongo(df):
    data = df.to_dict("records")
    collection.delete_many({})
    collection.insert_many(data)
    return "ok"

@flow
def pipeline_parte3():
    df_local = pd.read_csv("staging/youtube_processed/youtube_top100_global.csv")
    guardar_mongo(df_local)

pipeline_parte3()
# Out:
# 07:53:17.199 | INFO    | Flow run 'fabulous-monkey' - Beginning flow run 'fabulous-monkey' for flow 'pipeline-parte3'
# 07:53:18.286 | INFO    | Task run 'guardar_mongo-5ae' - Finished in state Completed()
# 07:53:19.222 | INFO    | Flow run 'fabulous-monkey' - Finished in state Completed()

# %% [markdown]
# ##  Verificación de datos almacenados en MongoDB

# %%
# Ver cuántos documentos hay
print("Total documentos:", collection.count_documents({}))

# Ver uno de ejemplo
print(collection.find_one())
# Out:
# Total documentos: 100
# {'_id': ObjectId('69f1ff3d8e5fd16def132f4f'), 'video_id': 'kiZmVObTXgX', 'trending_date': '18.11.02', 'title': 'Video DE #003', 'channel_title': 'Channel_2', 'category_id': 15, 'publish_time': '2018-02-08T21:13:00.000Z', 'tags': 'tag1|tag2', 'views': 49975127, 'likes': 1792362, 'dislikes': 97081, 'comment_count': 109858, 'thumbnail_link': 'https://example.com/thumb.jpg', 'comments_disabled': False, 'ratings_disabled': False, 'video_error_or_removed': False, 'description': 'Descripción del vídeo de muestra.', 'country': 'DE', 'trending_date_std': '2018-02-11', 'publish_time_std': '2018-02-08 21:13:00', 'trending_date_std_iter': '2018-02-11', 'publish_time_std_iter': '2018-02-08 21:13:00', 'delta_tendencia': '2 days 02:47:00', 'dias_hasta_tendencia': 2, 'horas_hasta_tendencia': 50.78333333333333, 'categoria_velocidad': 'rapido'}

# %% [markdown]
# ## Preparación de datos para análisis y visualización

# %%
import pandas as pd

df = pd.read_csv("staging/youtube_processed/youtube_top100_global.csv")

# %% [markdown]
# ## Configuración del renderizado de gráficos con Plotly

# %%
import plotly.io as pio
pio.renderers.default = "browser"

fig.show()

# %% [markdown]
# ## Visualización geográfica de la categoría más vista por país

# %%
cat_top = df.groupby(["country", "category_id"])["views"].sum().reset_index()
cat_top = cat_top.loc[cat_top.groupby("country")["views"].idxmax()]

fig = px.choropleth(
    cat_top,
    locations="country",
    locationmode="country names",
    color="category_id",
    title="Categoría más vista por país"
)

fig.show()
# Out:
# C:\Users\saran\AppData\Local\Temp\ipykernel_2352\1427386347.py:4: DeprecationWarning: The library used by the *country names* `locationmode` option is changing in an upcoming version. Country names in existing plots may not work in the new version. To ensure consistent behavior, consider setting `locationmode` to *ISO-3*.
#   fig = px.choropleth(

# %% [markdown]
# ## Cálculo de la correlación entre tiempo en tendencia y número de vistas

# %%
correlacion = df["dias_hasta_tendencia"].corr(df["views"])
print("Correlación:", correlacion)
# Out:
# Correlación: -0.11012469941253515

# %% [markdown]
# ## Visualización de la correlación entre tiempo en tendencia y vistas (regresión OLS)

# %%
fig = px.scatter(
    df,
    x="dias_hasta_tendencia",
    y="views",
    trendline="ols",
    title="Relación entre tiempo en tendencia y vistas"
)

fig.show()
